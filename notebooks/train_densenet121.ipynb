# %% [markdown]
# # DenseNet121 — Optimized Transfer Learning Notebook

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip -q install scikit-learn opencv-python-headless

# %%
import os
import gc
import json
import math
import glob
import shutil
import random
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import mixed_precision
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import classification_report, confusion_matrix, f1_score, accuracy_score

from tensorflow.keras.applications.densenet import preprocess_input

print("TensorFlow:", tf.__version__)
print("GPU:", tf.config.list_physical_devices('GPU'))

mixed_precision.set_global_policy("mixed_float16")

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

DRIVE_ROOT = Path("/content/drive/MyDrive/Skin Disease Detection")
DRIVE_DATA_DIR = DRIVE_ROOT / "skin-data"
LOCAL_DATA_DIR = Path("/content/skin-data")
OUTPUT_DIR = DRIVE_ROOT / "outputs_densenet121_opt8"

IMG_SIZE = (224, 224)
BATCH_SIZE = 32

EPOCHS_PHASE1 = 12
EPOCHS_PHASE2 = 12
EPOCHS_PHASE3 = 18

RESET_LOCAL_COPY = True       # đổi False nếu muốn giữ local copy cũ
USE_FOCAL_LOSS = True         # True khuyên dùng cho dataset lệch class
FOCAL_GAMMA = 2.0
FOCAL_ALPHA = 0.25

OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
# Out:
# TensorFlow: 2.20.0
# GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## 1. Kiểm tra dữ liệu trên Drive

# %%
assert DRIVE_DATA_DIR.exists(), f"Không tìm thấy {DRIVE_DATA_DIR}"

for split in ["train", "val", "test"]:
    split_dir = DRIVE_DATA_DIR / split
    assert split_dir.exists(), f"Không tìm thấy {split_dir}"
    classes = sorted([x.name for x in split_dir.iterdir() if x.is_dir()])
    print(split, len(classes), classes)
# Out:
# train 8 ['acne_rosacea', 'atopic_dermatitis', 'bullous_disease', 'eczema', 'nail_fungus', 'tinea', 'vitiligo', 'warts']
# val 8 ['acne_rosacea', 'atopic_dermatitis', 'bullous_disease', 'eczema', 'nail_fungus', 'tinea', 'vitiligo', 'warts']
# test 8 ['acne_rosacea', 'atopic_dermatitis', 'bullous_disease', 'eczema', 'nail_fungus', 'tinea', 'vitiligo', 'warts']

# %% [markdown]
# ## 2. Reset local copy và copy data từ Drive về local
#
# Nếu bạn vừa đổi số class, nên để `RESET_LOCAL_COPY = True`.

# %%
if RESET_LOCAL_COPY and LOCAL_DATA_DIR.exists():
    shutil.rmtree(LOCAL_DATA_DIR)
    print("Đã xóa local skin-data cũ")

if not LOCAL_DATA_DIR.exists():
    print("Đang copy dữ liệu từ Drive về local...")
    shutil.copytree(DRIVE_DATA_DIR, LOCAL_DATA_DIR)
    print("Copy xong.")
else:
    print("Local data đã tồn tại, bỏ qua copy.")

TRAIN_DIR = LOCAL_DATA_DIR / "train"
VAL_DIR   = LOCAL_DATA_DIR / "val"
TEST_DIR  = LOCAL_DATA_DIR / "test"
# Out:
# Đang copy dữ liệu từ Drive về local...
# Copy xong.

# %% [markdown]
# ## 3. Đọc class và thống kê dữ liệu

# %%
CLASS_NAMES = sorted([d.name for d in TRAIN_DIR.iterdir() if d.is_dir()])
NUM_CLASSES = len(CLASS_NAMES)

print("NUM_CLASSES =", NUM_CLASSES)
print(CLASS_NAMES)

def count_images(folder, class_names):
    exts = {".jpg", ".jpeg", ".png", ".bmp", ".webp"}
    rows = []
    for cls in class_names:
        n = sum(1 for f in (folder / cls).iterdir() if f.suffix.lower() in exts)
        rows.append({"class_name": cls, "count": n})
    return pd.DataFrame(rows)

train_df = count_images(TRAIN_DIR, CLASS_NAMES).rename(columns={"count": "train"})
val_df   = count_images(VAL_DIR, CLASS_NAMES).rename(columns={"count": "val"})
test_df  = count_images(TEST_DIR, CLASS_NAMES).rename(columns={"count": "test"})

stats_df = train_df.merge(val_df, on="class_name").merge(test_df, on="class_name")
stats_df["total"] = stats_df["train"] + stats_df["val"] + stats_df["test"]
display(stats_df.sort_values("total", ascending=False))

with open(OUTPUT_DIR / "class_names.json", "w", encoding="utf-8") as f:
    json.dump(CLASS_NAMES, f, indent=2, ensure_ascii=False)
# Out:
# NUM_CLASSES = 8
# ['acne_rosacea', 'atopic_dermatitis', 'bullous_disease', 'eczema', 'nail_fungus', 'tinea', 'vitiligo', 'warts']
#           class_name  train  val  test  total
# 5              tinea   1605  344   345   2294
# 3             eczema   1251  268   269   1788
# 1  atopic_dermatitis    842  180   181   1203
# 0       acne_rosacea    773  165   167   1105
# 7              warts    760  162   164   1086
# 6           vitiligo    718  153   155   1026
# 4        nail_fungus    600  128   130    858
# 2    bullous_disease    313   67    68    448

# %% [markdown]
# ## 4. Tạo dataset

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    TRAIN_DIR,
    labels="inferred",
    label_mode="int",
    class_names=CLASS_NAMES,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=True,
    seed=SEED,
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    VAL_DIR,
    labels="inferred",
    label_mode="int",
    class_names=CLASS_NAMES,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False,
)

test_ds = tf.keras.utils.image_dataset_from_directory(
    TEST_DIR,
    labels="inferred",
    label_mode="int",
    class_names=CLASS_NAMES,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False,
)

AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.prefetch(AUTOTUNE)
val_ds   = val_ds.prefetch(AUTOTUNE)
test_ds  = test_ds.prefetch(AUTOTUNE)
# Out:
# Found 6862 files belonging to 8 classes.
# Found 1467 files belonging to 8 classes.
# Found 1479 files belonging to 8 classes.

# %% [markdown]
# ## 5. Class weights

# %%
y_train = []
train_for_weights = tf.keras.utils.image_dataset_from_directory(
    TRAIN_DIR,
    labels="inferred",
    label_mode="int",
    class_names=CLASS_NAMES,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False,
)
for _, labels in train_for_weights:
    y_train.extend(labels.numpy().tolist())

weights = compute_class_weight(
    class_weight="balanced",
    classes=np.arange(NUM_CLASSES),
    y=np.array(y_train)
)
CLASS_WEIGHT = {i: float(w) for i, w in enumerate(weights)}

for i, cls in enumerate(CLASS_NAMES):
    print(f"{cls:<24s}: {CLASS_WEIGHT[i]:.3f}")
# Out:
# Found 6862 files belonging to 8 classes.
# acne_rosacea            : 1.110
# atopic_dermatitis       : 1.019
# bullous_disease         : 2.740
# eczema                  : 0.686
# nail_fungus             : 1.430
# tinea                   : 0.534
# vitiligo                : 1.195
# warts                   : 1.129

# %% [markdown]
# ## 6. Focal Loss

# %%
class SparseCategoricalFocalLoss(keras.losses.Loss):
    def __init__(self, gamma=2.0, alpha=0.25, name="sparse_categorical_focal_loss"):
        super().__init__(name=name)
        self.gamma = gamma
        self.alpha = alpha

    def call(self, y_true, y_pred):
        y_true = tf.cast(tf.reshape(y_true, [-1]), tf.int32)
        y_pred = tf.clip_by_value(y_pred, 1e-7, 1.0 - 1e-7)

        y_true_one_hot = tf.one_hot(y_true, depth=tf.shape(y_pred)[-1])
        ce = -y_true_one_hot * tf.math.log(y_pred)
        p_t = y_true_one_hot * y_pred
        focal = self.alpha * tf.pow(1.0 - p_t, self.gamma) * ce
        return tf.reduce_sum(focal, axis=-1)

    def get_config(self):
        return {"gamma": self.gamma, "alpha": self.alpha}

# %% [markdown]
# ## 7. Data augmentation

# %%
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.08),
    layers.RandomZoom(0.10),
    layers.RandomTranslation(0.05, 0.05),
    layers.RandomContrast(0.15),
], name="augmentation")

# %% [markdown]
# ## 8. Build model — DenseNet121

# %%
def build_model(num_classes):
    inputs = keras.Input(shape=(IMG_SIZE[0], IMG_SIZE[1], 3), name="image")
    x = data_augmentation(inputs)
    x = layers.Activation("linear", dtype="float32", name="cast_to_float32")(x)
    x = preprocess_input(x)

    backbone = tf.keras.applications.DenseNet121(include_top=False, weights="imagenet", input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3))
    backbone.trainable = False

    x = backbone(x, training=False)
    x = layers.GlobalAveragePooling2D(name="gap")(x)
    x = layers.BatchNormalization(name="bn_head")(x)
    x = layers.Dropout(0.45, name="dropout_1")(x)
    x = layers.Dense(256, activation="relu", name="dense_256")(x)
    x = layers.Dropout(0.35, name="dropout_2")(x)

    outputs = layers.Dense(
        num_classes,
        activation="softmax",
        dtype="float32",
        name="predictions"
    )(x)

    model = keras.Model(inputs, outputs, name="DenseNet121")
    return model, backbone

model, backbone = build_model(NUM_CLASSES)
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "DenseNet121"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ image (InputLayer)              │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ augmentation (Sequential)       │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ cast_to_float32 (Activation)    │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ true_divide (TrueDivide)        │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ add (Add)                       │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ true_divide_1 (TrueDivide)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ densenet121 (Functional)        │ (None, 7, 7, 1024)     │     7,037,504 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gap (GlobalAveragePooling2D)    │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bn_head (BatchNormalization)    │ (None, 1024)           │         4,096 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_256 (Dense)               │ (None, 256)            │       262,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ predictions (Dense)             │ (None, 8)              │         2,056 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,306,056 (27.87 MB)
#  Trainable params: 266,504 (1.02 MB)
#  Non-trainable params: 7,039,552 (26.85 MB)

# %% [markdown]
# ## 9. Compile / callbacks / unfreeze helpers

# %%
def compile_model(model, lr):
    loss_fn = SparseCategoricalFocalLoss(gamma=FOCAL_GAMMA, alpha=FOCAL_ALPHA) if USE_FOCAL_LOSS else "sparse_categorical_crossentropy"
    optimizer = keras.optimizers.Adam(learning_rate=lr, clipnorm=1.0)

    model.compile(
        optimizer=optimizer,
        loss=loss_fn,
        metrics=["accuracy"]
    )

def make_callbacks(tag):
    return [
        keras.callbacks.ModelCheckpoint(
            OUTPUT_DIR / f"{tag}.keras",
            monitor="val_accuracy",
            save_best_only=True,
            mode="max",
            verbose=1,
        ),
        keras.callbacks.EarlyStopping(
            monitor="val_accuracy",
            patience=5,
            restore_best_weights=True,
            mode="max",
            verbose=1,
        ),
        keras.callbacks.ReduceLROnPlateau(
            monitor="val_loss",
            factor=0.3,
            patience=2,
            min_lr=1e-7,
            verbose=1,
        ),
    ]

def set_trainable_ratio(backbone, ratio):
    backbone.trainable = True
    n = len(backbone.layers)
    start = int(n * (1 - ratio))
    for layer in backbone.layers[:start]:
        layer.trainable = False
    for layer in backbone.layers[start:]:
        if isinstance(layer, layers.BatchNormalization):
            layer.trainable = False
        else:
            layer.trainable = True

    trainable = sum(int(layer.trainable) for layer in backbone.layers)
    print(f"Backbone trainable layers: {trainable}/{n}")

# %% [markdown]
# ## 10. Train — Phase 1

# %%
compile_model(model, lr=1e-3)
history1 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS_PHASE1,
    class_weight=CLASS_WEIGHT,
    callbacks=make_callbacks("best_phase1"),
    verbose=1,
)
# Out:
# Epoch 1/12
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.3642 - loss: 0.3709
# Epoch 1: val_accuracy improved from None to 0.51602, saving model to /content/drive/MyDrive/Skin Disease Detection/outputs_densenet121_opt8/best_phase1.keras
#
# Epoch 1: finished saving model to /content/drive/MyDrive/Skin Disease Detection/outputs_densenet121_opt8/best_phase1.keras
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 73s 198ms/step - accuracy: 0.4266 - loss: 0.3055 - val_accuracy: 0.5160 - val_loss: 0.2201 - learning_rate: 0.0010
# Epoch 2/12
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.5194 - loss: 0.2042
# Epoch 2: val_accuracy improved from 0.51602 to 0.55078, saving model to /content/drive/MyDrive/Skin Disease Detection/outputs_densenet121_opt8/best_phase1.keras
#
# Epoch 2: finished saving model to /content/drive/MyDrive/Skin Disease Detection/outputs_densenet121_opt8/best_phase1.keras
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 41s 189ms/step - accuracy: 0.5208 - loss: 0.2029 - val_accuracy: 0.5508 - val_loss: 0.1922 - learning_rate: 0.0010
# Epoch 3/12
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.5334 - loss: 0.1855
# Epoch 3: val_accuracy improved from 0.55078 to 0.56169, saving model to /content/drive/MyDrive/Skin Disease Detection/outputs_densenet121_opt8/best_phase1.keras
#
# Epoch 3: finished saving model to /content/drive/MyDrive/Skin Disease Detection/outputs_densenet121_opt8/best_phase1.keras
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 39s 178ms/step - accuracy: 0.5388 - loss: 0.1799 - val_accuracy: 0.5617 - val_loss: 0.1831 - learning_rate: 0.0010
# Epoch 4/12
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.5754 - loss: 0.1602
# Epoch 4: val_accuracy improved from 0.56169 to 0.57260, saving model to /content/drive/MyDrive/Skin Disease Detection/outputs_densenet121_opt8/best_phase1.keras
#
# Epoch 4: finished saving model to /content/drive/MyDrive/Skin Disease Detection/outputs_densenet121_opt8/best_phase1.keras
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 38s 176ms/step - accuracy: 0.5737 - loss: 0.1603 - val_accuracy: 0.5726 - val_loss: 0.1797 - learning_rate: 0.0010
# Epoch 5/12
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.5864 - loss: 0.1549
# Epoch 5: val_accuracy improved from 0.57260 to 0.59441, saving model to /content/drive/MyDrive/Skin Disease Detection/outputs_densenet121_opt8/best_phase1.keras
#
# Epoch 5: finished saving model to /content/drive/MyDrive/Skin Disease Detection/outputs_densenet121_opt8/best_phase1.keras
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 39s 180ms/step - accuracy: 0.5928 - loss: 0.1504 - val_accuracy: 0.5944 - val_loss: 0.1666 - learning_rate: 0.0010
# Epoch 6/12
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.6038 - loss: 0.1456
# Epoch 6: val_accuracy did not improve from 0.59441
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 35s 164ms/step - accuracy: 0.5995 - loss: 0.1479 - val_accuracy: 0.5869 - val_loss: 0.1790 - learning_rate: 0.0010
# Epoch 7/12
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.5983 - loss: 0.1451
# Epoch 7: val_accuracy improved from 0.59441 to 0.60123, saving model to /content/drive/MyDrive/Skin Disease Detection/outputs_densenet121_opt8/best_phase1.keras
#
# Epoch 7: finished saving model to /content/drive/MyDrive/Skin Disease Detection/outputs_densenet121_opt8/best_phase1.keras
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 39s 181ms/step - accuracy: 0.6029 - loss: 0.1435 - val_accuracy: 0.6012 - val_loss: 0.1769 - learning_rate: 0.0010
# Epoch 8/12
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.6196 - loss: 0.1370
# Epoch 8: val_accuracy improved from 0.60123 to 0.61963, saving model to /content/drive/MyDrive/Skin Disease Detection/outputs_densenet121_opt8/best_phase1.keras
#
# Epoch 8: finished saving model to /content/drive/MyDrive/Skin Disease Detection/outputs_densenet121_opt8/best_phase1.keras
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 44s 195ms/step - accuracy: 0.6293 - loss: 0.1327 - val_accuracy: 0.6196 - val_loss: 0.1641 - learning_rate: 3.0000e-04
# Epoch 9/12
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.6203 - loss: 0.1380
# Epoch 9: val_accuracy improved from 0.61963 to 0.63122, saving model to /content/drive/MyDrive/Skin Disease Detection/outputs_densenet121_opt8/best_phase1.keras
#
# Epoch 9: finished saving model to /content/drive/MyDrive/Skin Disease Detection/outputs_densenet121_opt8/best_phase1.keras
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 38s 178ms/step - accuracy: 0.6377 - loss: 0.1290 - val_accuracy: 0.6312 - val_loss: 0.1583 - learning_rate: 3.0000e-04
# Epoch 10/12
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.6352 - loss: 0.1302
# Epoch 10: val_accuracy improved from 0.63122 to 0.64281, saving model to /content/drive/MyDrive/Skin Disease Detection/outputs_densenet121_opt8/best_phase1.keras
#
# Epoch 10: finished saving model to /content/drive/MyDrive/Skin Disease Detection/outputs_densenet121_opt8/best_phase1.keras
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 41s 192ms/step - accuracy: 0.6396 - loss: 0.1282 - val_accuracy: 0.6428 - val_loss: 0.1556 - learning_rate: 3.0000e-04
# Epoch 11/12
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.6435 - loss: 0.1270
# Epoch 11: val_accuracy improved from 0.64281 to 0.64826, saving model to /content/drive/MyDrive/Skin Disease Detection/outputs_densenet121_opt8/best_phase1.keras
#
# Epoch 11: finished saving model to /content/drive/MyDrive/Skin Disease Detection/outputs_densenet121_opt8/best_phase1.keras
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 41s 193ms/step - accuracy: 0.6495 - loss: 0.1231 - val_accuracy: 0.6483 - val_loss: 0.1492 - learning_rate: 3.0000e-04
# Epoch 12/12
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.6387 - loss: 0.1277
# Epoch 12: val_accuracy did not improve from 0.64826
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 41s 189ms/step - accuracy: 0.6484 - loss: 0.1232 - val_accuracy: 0.6367 - val_loss: 0.1531 - learning_rate: 3.0000e-04
# Restoring model weights from the end of the best epoch: 11.

# %% [markdown]
# ## 11. Train — Phase 2

# %%
set_trainable_ratio(backbone, ratio=0.45)
compile_model(model, lr=1e-4)
history2 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS_PHASE2,
    class_weight=CLASS_WEIGHT,
    callbacks=make_callbacks("best_phase2"),
    verbose=1,
)
# Out:
# Backbone trainable layers: 138/427
# Epoch 1/12
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.6093 - loss: 0.1430
# Epoch 1: val_accuracy improved from None to 0.61077, saving model to /content/drive/MyDrive/Skin Disease Detection/outputs_densenet121_opt8/best_phase2.keras
#
# Epoch 1: finished saving model to /content/drive/MyDrive/Skin Disease Detection/outputs_densenet121_opt8/best_phase2.keras
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 87s 244ms/step - accuracy: 0.6097 - loss: 0.1423 - val_accuracy: 0.6108 - val_loss: 0.1667 - learning_rate: 1.0000e-04
# Epoch 2/12
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.6295 - loss: 0.1332
# Epoch 2: val_accuracy did not improve from 0.61077
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 45s 208ms/step - accuracy: 0.6275 - loss: 0.1315 - val_accuracy: 0.5562 - val_loss: 0.2385 - learning_rate: 1.0000e-04
# Epoch 3/12
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.6451 - loss: 0.1234
# Epoch 3: val_accuracy improved from 0.61077 to 0.62168, saving model to /content/drive/MyDrive/Skin Disease Detection/outputs_densenet121_opt8/best_phase2.keras
#
# Epoch 3: finished saving model to /content/drive/MyDrive/Skin Disease Detection/outputs_densenet121_opt8/best_phase2.keras
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 83s 215ms/step - accuracy: 0.6516 - loss: 0.1194 - val_accuracy: 0.6217 - val_loss: 0.1633 - learning_rate: 1.0000e-04
# Epoch 4/12
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.6677 - loss: 0.1161
# Epoch 4: val_accuracy improved from 0.62168 to 0.66462, saving model to /content/drive/MyDrive/Skin Disease Detection/outputs_densenet121_opt8/best_phase2.keras
#
# Epoch 4: finished saving model to /content/drive/MyDrive/Skin Disease Detection/outputs_densenet121_opt8/best_phase2.keras
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 51s 237ms/step - accuracy: 0.6755 - loss: 0.1117 - val_accuracy: 0.6646 - val_loss: 0.1312 - learning_rate: 1.0000e-04
# Epoch 5/12
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.6806 - loss: 0.1077
# Epoch 5: val_accuracy improved from 0.66462 to 0.67007, saving model to /content/drive/MyDrive/Skin Disease Detection/outputs_densenet121_opt8/best_phase2.keras
#
# Epoch 5: finished saving model to /content/drive/MyDrive/Skin Disease Detection/outputs_densenet121_opt8/best_phase2.keras
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 83s 241ms/step - accuracy: 0.6900 - loss: 0.1032 - val_accuracy: 0.6701 - val_loss: 0.1457 - learning_rate: 1.0000e-04
# Epoch 6/12
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.7078 - loss: 0.1020
# Epoch 6: val_accuracy did not improve from 0.67007
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 44s 206ms/step - accuracy: 0.7074 - loss: 0.0995 - val_accuracy: 0.6612 - val_loss: 0.1387 - learning_rate: 1.0000e-04
# Epoch 7/12
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.7273 - loss: 0.0875
# Epoch 7: val_accuracy improved from 0.67007 to 0.70484, saving model to /content/drive/MyDrive/Skin Disease Detection/outputs_densenet121_opt8/best_phase2.keras
#
# Epoch 7: finished saving model to /content/drive/MyDrive/Skin Disease Detection/outputs_densenet121_opt8/best_phase2.keras
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 45s 210ms/step - accuracy: 0.7348 - loss: 0.0821 - val_accuracy: 0.7048 - val_loss: 0.1254 - learning_rate: 3.0000e-05
# Epoch 8/12
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.7522 - loss: 0.0768
# Epoch 8: val_accuracy did not improve from 0.70484
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 49s 225ms/step - accuracy: 0.7549 - loss: 0.0743 - val_accuracy: 0.7021 - val_loss: 0.1228 - learning_rate: 3.0000e-05
# Epoch 9/12
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.7585 - loss: 0.0740
# Epoch 9: val_accuracy improved from 0.70484 to 0.70757, saving model to /content/drive/MyDrive/Skin Disease Detection/outputs_densenet121_opt8/best_phase2.keras
#
# Epoch 9: finished saving model to /content/drive/MyDrive/Skin Disease Detection/outputs_densenet121_opt8/best_phase2.keras
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 49s 228ms/step - accuracy: 0.7620 - loss: 0.0713 - val_accuracy: 0.7076 - val_loss: 0.1219 - learning_rate: 3.0000e-05
# Epoch 10/12
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.7609 - loss: 0.0739
# Epoch 10: val_accuracy improved from 0.70757 to 0.71097, saving model to /content/drive/MyDrive/Skin Disease Detection/outputs_densenet121_opt8/best_phase2.keras
#
# Epoch 10: finished saving model to /content/drive/MyDrive/Skin Disease Detection/outputs_densenet121_opt8/best_phase2.keras
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 52s 241ms/step - accuracy: 0.7641 - loss: 0.0707 - val_accuracy: 0.7110 - val_loss: 0.1211 - learning_rate: 3.0000e-05
# Epoch 11/12
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.7681 - loss: 0.0677
# Epoch 11: val_accuracy improved from 0.71097 to 0.71234, saving model to /content/drive/MyDrive/Skin Disease Detection/outputs_densenet121_opt8/best_phase2.keras
#
# Epoch 11: finished saving model to /content/drive/MyDrive/Skin Disease Detection/outputs_densenet121_opt8/best_phase2.keras
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 48s 222ms/step - accuracy: 0.7746 - loss: 0.0666 - val_accuracy: 0.7123 - val_loss: 0.1263 - learning_rate: 3.0000e-05
# Epoch 12/12
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.7778 - loss: 0.0639
# Epoch 12: val_accuracy improved from 0.71234 to 0.73006, saving model to /content/drive/MyDrive/Skin Disease Detection/outputs_densenet121_opt8/best_phase2.keras
#
# Epoch 12: finished saving model to /content/drive/MyDrive/Skin Disease Detection/outputs_densenet121_opt8/best_phase2.keras
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 84s 233ms/step - accuracy: 0.7821 - loss: 0.0625 - val_accuracy: 0.7301 - val_loss: 0.1158 - learning_rate: 3.0000e-05
# Restoring model weights from the end of the best epoch: 12.

# %% [markdown]
# ## 12. Train — Phase 3

# %%
set_trainable_ratio(backbone, ratio=0.80)
compile_model(model, lr=5e-5)
history3 = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS_PHASE3,
    class_weight=CLASS_WEIGHT,
    callbacks=make_callbacks("best_final"),
    verbose=1,
)

histories = {
    "phase1": history1.history,
    "phase2": history2.history,
    "phase3": history3.history,
}

with open(OUTPUT_DIR / "history.json", "w", encoding="utf-8") as f:
    json.dump(histories, f, indent=2)
# Out:
# Backbone trainable layers: 245/427
# Epoch 1/18
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.7436 - loss: 0.0787
# Epoch 1: val_accuracy improved from None to 0.70893, saving model to /content/drive/MyDrive/Skin Disease Detection/outputs_densenet121_opt8/best_final.keras
#
# Epoch 1: finished saving model to /content/drive/MyDrive/Skin Disease Detection/outputs_densenet121_opt8/best_final.keras
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 107s 316ms/step - accuracy: 0.7474 - loss: 0.0783 - val_accuracy: 0.7089 - val_loss: 0.1205 - learning_rate: 5.0000e-05
# Epoch 2/18
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.7480 - loss: 0.0780
# Epoch 2: val_accuracy did not improve from 0.70893
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 71s 281ms/step - accuracy: 0.7553 - loss: 0.0739 - val_accuracy: 0.6892 - val_loss: 0.1310 - learning_rate: 5.0000e-05
# Epoch 3/18
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 0.7699 - loss: 0.0682
# Epoch 3: val_accuracy did not improve from 0.70893
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 1.4999999621068127e-05.
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 52s 242ms/step - accuracy: 0.7649 - loss: 0.0683 - val_accuracy: 0.6639 - val_loss: 0.1666 - learning_rate: 5.0000e-05
# Epoch 4/18
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.7898 - loss: 0.0619
# Epoch 4: val_accuracy improved from 0.70893 to 0.73483, saving model to /content/drive/MyDrive/Skin Disease Detection/outputs_densenet121_opt8/best_final.keras
#
# Epoch 4: finished saving model to /content/drive/MyDrive/Skin Disease Detection/outputs_densenet121_opt8/best_final.keras
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 55s 256ms/step - accuracy: 0.7998 - loss: 0.0565 - val_accuracy: 0.7348 - val_loss: 0.1053 - learning_rate: 1.5000e-05
# Epoch 5/18
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.8179 - loss: 0.0532
# Epoch 5: val_accuracy improved from 0.73483 to 0.75187, saving model to /content/drive/MyDrive/Skin Disease Detection/outputs_densenet121_opt8/best_final.keras
#
# Epoch 5: finished saving model to /content/drive/MyDrive/Skin Disease Detection/outputs_densenet121_opt8/best_final.keras
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 55s 256ms/step - accuracy: 0.8146 - loss: 0.0506 - val_accuracy: 0.7519 - val_loss: 0.1012 - learning_rate: 1.5000e-05
# Epoch 6/18
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.8147 - loss: 0.0497
# Epoch 6: val_accuracy improved from 0.75187 to 0.75528, saving model to /content/drive/MyDrive/Skin Disease Detection/outputs_densenet121_opt8/best_final.keras
#
# Epoch 6: finished saving model to /content/drive/MyDrive/Skin Disease Detection/outputs_densenet121_opt8/best_final.keras
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 85s 272ms/step - accuracy: 0.8177 - loss: 0.0477 - val_accuracy: 0.7553 - val_loss: 0.0975 - learning_rate: 1.5000e-05
# Epoch 7/18
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.8303 - loss: 0.0457
# Epoch 7: val_accuracy improved from 0.75528 to 0.76619, saving model to /content/drive/MyDrive/Skin Disease Detection/outputs_densenet121_opt8/best_final.keras
#
# Epoch 7: finished saving model to /content/drive/MyDrive/Skin Disease Detection/outputs_densenet121_opt8/best_final.keras
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 55s 256ms/step - accuracy: 0.8326 - loss: 0.0445 - val_accuracy: 0.7662 - val_loss: 0.0928 - learning_rate: 1.5000e-05
# Epoch 8/18
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.8251 - loss: 0.0471
# Epoch 8: val_accuracy did not improve from 0.76619
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 53s 246ms/step - accuracy: 0.8328 - loss: 0.0444 - val_accuracy: 0.7498 - val_loss: 0.1082 - learning_rate: 1.5000e-05
# Epoch 9/18
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.8350 - loss: 0.0436
# Epoch 9: val_accuracy did not improve from 0.76619
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 4.499999886320438e-06.
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 56s 260ms/step - accuracy: 0.8409 - loss: 0.0415 - val_accuracy: 0.7573 - val_loss: 0.1049 - learning_rate: 1.5000e-05
# Epoch 10/18
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.8417 - loss: 0.0404
# Epoch 10: val_accuracy did not improve from 0.76619
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 83s 264ms/step - accuracy: 0.8496 - loss: 0.0377 - val_accuracy: 0.7614 - val_loss: 0.1030 - learning_rate: 4.5000e-06
# Epoch 11/18
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step - accuracy: 0.8528 - loss: 0.0375
# Epoch 11: val_accuracy did not improve from 0.76619
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 1.3499999113264492e-06.
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 79s 248ms/step - accuracy: 0.8595 - loss: 0.0356 - val_accuracy: 0.7635 - val_loss: 0.0977 - learning_rate: 4.5000e-06
# Epoch 12/18
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.8648 - loss: 0.0336
# Epoch 12: val_accuracy did not improve from 0.76619
# 215/215 ━━━━━━━━━━━━━━━━━━━━ 52s 243ms/step - accuracy: 0.8674 - loss: 0.0332 - val_accuracy: 0.7601 - val_loss: 0.1010 - learning_rate: 1.3500e-06
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 7.

# %% [markdown]
# ## 13. Vẽ learning curves

# %%
acc = histories["phase1"]["accuracy"] + histories["phase2"]["accuracy"] + histories["phase3"]["accuracy"]
val_acc = histories["phase1"]["val_accuracy"] + histories["phase2"]["val_accuracy"] + histories["phase3"]["val_accuracy"]
loss = histories["phase1"]["loss"] + histories["phase2"]["loss"] + histories["phase3"]["loss"]
val_loss = histories["phase1"]["val_loss"] + histories["phase2"]["val_loss"] + histories["phase3"]["val_loss"]

x = range(1, len(acc) + 1)
p2_start = len(histories["phase1"]["accuracy"]) + 1
p3_start = p2_start + len(histories["phase2"]["accuracy"])

plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(x, acc, label="Train")
plt.plot(x, val_acc, label="Val")
plt.axvline(p2_start, linestyle="--", alpha=0.7)
plt.axvline(p3_start, linestyle="--", alpha=0.7)
plt.title("Accuracy")
plt.xlabel("Epoch")
plt.legend()
plt.grid(alpha=0.3)

plt.subplot(1, 2, 2)
plt.plot(x, loss, label="Train")
plt.plot(x, val_loss, label="Val")
plt.axvline(p2_start, linestyle="--", alpha=0.7)
plt.axvline(p3_start, linestyle="--", alpha=0.7)
plt.title("Loss")
plt.xlabel("Epoch")
plt.legend()
plt.grid(alpha=0.3)

plt.tight_layout()
plt.savefig(OUTPUT_DIR / "training_curves.png", dpi=180)
plt.show()

# %% [markdown]
# ## 14. Load best model để đánh giá

# %%
custom_objects = {
    "SparseCategoricalFocalLoss": SparseCategoricalFocalLoss,
}

best_model = keras.models.load_model(
    OUTPUT_DIR / "best_final.keras",
    custom_objects=custom_objects
)

# %% [markdown]
# ## 15. Đánh giá trên test set

# %%
y_true, y_pred, y_prob = [], [], []
for images, labels in test_ds:
    probs = best_model(images, training=False).numpy()
    preds = np.argmax(probs, axis=1)
    y_true.extend(labels.numpy().tolist())
    y_pred.extend(preds.tolist())
    y_prob.extend(probs.tolist())

y_true = np.array(y_true)
y_pred = np.array(y_pred)

acc = accuracy_score(y_true, y_pred)
macro_f1 = f1_score(y_true, y_pred, average="macro")
weighted_f1 = f1_score(y_true, y_pred, average="weighted")

print(f"Test Accuracy : {acc:.4f} ({acc*100:.2f}%)")
print(f"Macro F1      : {macro_f1:.4f}")
print(f"Weighted F1   : {weighted_f1:.4f}")

report = classification_report(y_true, y_pred, target_names=CLASS_NAMES, digits=4, output_dict=True)
report_df = pd.DataFrame(report).T
display(report_df)
report_df.to_csv(OUTPUT_DIR / "classification_report.csv", encoding="utf-8-sig")

with open(OUTPUT_DIR / "metrics.json", "w", encoding="utf-8") as f:
    json.dump({
        "test_accuracy": float(acc),
        "macro_f1": float(macro_f1),
        "weighted_f1": float(weighted_f1),
    }, f, indent=2)
# Out:
# Test Accuracy : 0.7748 (77.48%)
# Macro F1      : 0.7799
# Weighted F1   : 0.7746
#                    precision    recall  f1-score      support
# acne_rosacea        0.839506  0.814371  0.826748   167.000000
# atopic_dermatitis   0.651685  0.640884  0.646240   181.000000
# bullous_disease     0.681818  0.661765  0.671642    68.000000
# eczema              0.762931  0.657993  0.706587   269.000000
# nail_fungus         0.899281  0.961538  0.929368   130.000000
# tinea               0.756983  0.785507  0.770982   345.000000
# vitiligo            0.993056  0.922581  0.956522   155.000000
# warts               0.665000  0.810976  0.730769   164.000000
# accuracy            0.774848  0.774848  0.774848     0.774848
# macro avg           0.781283  0.781952  0.779857  1479.000000
# weighted avg        0.778089  0.774848  0.774640  1479.000000

# %% [markdown]
# ## 16. Confusion matrix

# %%
import seaborn as sns

cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(12, 9))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=CLASS_NAMES,
    yticklabels=CLASS_NAMES,
    linewidths=0.4,
    linecolor="#cccccc",
    annot_kws={"size": 9},
)
plt.title("Confusion Matrix — Test Set", fontsize=13, fontweight="bold", pad=12)
plt.xlabel("Predicted", fontsize=11)
plt.ylabel("True", fontsize=11)
plt.xticks(rotation=45, ha="right", fontsize=8)
plt.yticks(rotation=0, fontsize=8)
plt.tight_layout()
plt.savefig(OUTPUT_DIR / "confusion_matrix.png", dpi=180, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## 17. Grad-CAM

# %%
def make_gradcam_heatmap(img_array, model, pred_index=None):
    # Output của backbone call = input của layer "gap"
    gap_layer = model.get_layer("gap")
    conv_output_tensor = gap_layer.input  # tensor (batch, H, W, C) trong graph của model

    grad_model = keras.Model(
        inputs=model.input,
        outputs=[conv_output_tensor, model.output],
    )

    img_tensor = tf.cast(img_array, tf.float32)
    with tf.GradientTape() as tape:
        conv_outputs, predictions = grad_model(img_tensor, training=False)
        tape.watch(conv_outputs)
        if pred_index is None:
            pred_index = int(tf.argmax(predictions[0]))
        class_channel = predictions[:, pred_index]

    grads = tape.gradient(class_channel, conv_outputs)
    if grads is None:
        raise ValueError("Gradient is None. Run tf.config.run_functions_eagerly(True) first.")

    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))
    conv_outputs_np = conv_outputs[0].numpy()
    pooled_grads_np = pooled_grads.numpy()

    heatmap = np.sum(conv_outputs_np * pooled_grads_np, axis=-1)
    heatmap = np.maximum(heatmap, 0)
    heatmap = heatmap / (np.max(heatmap) + 1e-8)
    return heatmap


def show_gradcam(image_path, model):
    img = keras.utils.load_img(image_path, target_size=IMG_SIZE)
    img_array = keras.utils.img_to_array(img).astype("float32")
    input_array = np.expand_dims(img_array, axis=0)

    preds = model(input_array, training=False).numpy()[0]
    pred_idx = int(np.argmax(preds))
    pred_name = CLASS_NAMES[pred_idx]
    conf = preds[pred_idx]

    heatmap = make_gradcam_heatmap(input_array, model, pred_idx)
    heatmap_resized = cv2.resize(heatmap.astype("float32"), IMG_SIZE)

    heatmap_uint8 = np.uint8(255 * heatmap_resized)
    heatmap_color = cv2.applyColorMap(heatmap_uint8, cv2.COLORMAP_JET)
    heatmap_color = cv2.cvtColor(heatmap_color, cv2.COLOR_BGR2RGB)

    overlay = np.clip(np.uint8(0.45 * heatmap_color + 0.55 * img_array), 0, 255)

    fig, axes = plt.subplots(1, 3, figsize=(13, 4))
    axes[0].imshow(np.uint8(img_array)); axes[0].axis("off"); axes[0].set_title("Original")
    axes[1].imshow(heatmap_resized, cmap="jet"); axes[1].axis("off"); axes[1].set_title("Heatmap")
    axes[2].imshow(overlay); axes[2].axis("off"); axes[2].set_title(f"{pred_name}\n{conf*100:.1f}%")
    plt.tight_layout()
    plt.show()

# %%
tf.config.run_functions_eagerly(True)

all_test_imgs = []
for cls in CLASS_NAMES:
    all_test_imgs.extend(glob.glob(str(TEST_DIR / cls / "*.jpg")))
    all_test_imgs.extend(glob.glob(str(TEST_DIR / cls / "*.jpeg")))
    all_test_imgs.extend(glob.glob(str(TEST_DIR / cls / "*.png")))

sample_imgs = random.sample(all_test_imgs, min(4, len(all_test_imgs)))
for p in sample_imgs:
    print(p)
    show_gradcam(p, best_model)
# Out:
# /content/skin-data/test/nail_fungus/nail_fungus_00003.jpg
# /content/skin-data/test/acne_rosacea/acne_rosacea_00159.jpg
# /content/skin-data/test/vitiligo/vitiligo_00041.jpeg
# /content/skin-data/test/tinea/tinea_00125.jpeg
